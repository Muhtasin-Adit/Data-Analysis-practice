# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv('example-df.csv')

# %%
df
# Out:
#      Name  ID  Age      City  Salary  Gender
# 0    Arif   1   23     Dhaka  25,000    Male
# 1   Samin   2   15     Dhaka  19,000    Male
# 2   Hamim   3   36    Sylhet  31,000    Male
# 3   Karim   4   23    Sylhet  20,000    Male
# 4     Roy   5   28   Jassore  24,000    Male
# 5  Edward   6   31   Jassore  31,000    Male
# 6   Russo   7   29  Hobiganj  27,000    Male
# 7   Raisa   8   24  Hobiganj  30,000  Female
# 8   Tabia   9   33    Khulna  26,000  Female

# %%
df.head(3)
# Out:
#     Name  ID  Age    City  Salary Gender
# 0   Arif   1   23   Dhaka  25,000   Male
# 1  Samin   2   15   Dhaka  19,000   Male
# 2  Hamim   3   36  Sylhet  31,000   Male

# %%
df.tail(2)
# Out:
#     Name  ID  Age      City  Salary  Gender
# 7  Raisa   8   24  Hobiganj  30,000  Female
# 8  Tabia   9   33    Khulna  26,000  Female

# %%
df.iloc[3]
# Out:
# Name       Karim
# ID             4
# Age           23
# City      Sylhet
# Salary    20,000
# Gender      Male
# Name: 3, dtype: object

# %%
a = df[df['Age']>28]

# %%
a
# Out:
#      Name  ID  Age      City  Salary  Gender
# 2   Hamim   3   36    Sylhet  31,000    Male
# 5  Edward   6   31   Jassore  31,000    Male
# 6   Russo   7   29  Hobiganj  27,000    Male
# 8   Tabia   9   33    Khulna  26,000  Female

# %%
df2 = pd.read_csv('houseprice.csv')

# %%
df2.head()
# Out:
#               date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02/05/2014 0:00   313000.0         3       1.50         1340      7912
# 1  02/05/2014 0:00  2384000.0         5       2.50         3650      9050
# 2  02/05/2014 0:00   342000.0         3       2.00         1930     11947
# 3  02/05/2014 0:00   420000.0         3       2.25         2000      8030
# 4  02/05/2014 0:00   550000.0         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df1 = df2.set_index(['city', 'date'])

# %%
df1.index
# Out:
# MultiIndex([(   'Shoreline', '02/05/2014 0:00'),
#             (     'Seattle', '02/05/2014 0:00'),
#             (        'Kent', '02/05/2014 0:00'),
#             (    'Bellevue', '02/05/2014 0:00'),
#             (     'Redmond', '02/05/2014 0:00'),
#             (     'Seattle', '02/05/2014 0:00'),
#             (     'Redmond', '02/05/2014 0:00'),
#             ('Maple Valley', '02/05/2014 0:00'),
#             (  'North Bend', '02/05/2014 0:00'),
#             (     'Seattle', '02/05/2014 0:00'),
#             ...
#             (      'Renton', '08/07/2014 0:00'),
#             (     'Seattle', '08/07/2014 0:00'),
#             ( 'Federal Way', '08/07/2014 0:00'),
#             (      'Auburn', '08/07/2014 0:00'),
#             (        'Kent', '09/07/2014 0:00'),
#             (     'Seattle', '09/07/2014 0:00'),
#             (    'Bellevue', '09/07/2014 0:00'),
#             (      'Renton', '09/07/2014 0:00'),
#             (     'Seattle', '10/07/2014 0:00'),
# ...

# %%
df1.loc['Seattle']
# Out:
#                         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 02/05/2014 0:00  2.384000e+06         5       2.50         3650      9050
# 02/05/2014 0:00  4.900000e+05         2       1.00          880      6380
# 02/05/2014 0:00  6.400000e+05         4       2.00         1520      6200
# 02/05/2014 0:00  1.400000e+06         4       2.50         2920      4000
# 02/05/2014 0:00  3.650000e+05         3       1.00         1090      6435
# ...                       ...       ...        ...          ...       ...
# 07/07/2014 0:00  4.060625e+05         2       1.00         1290      4650
# 07/07/2014 0:00  4.868950e+05         3       1.00         1890      3330
# 08/07/2014 0:00  3.961667e+05         3       1.75         1880      5752
# 09/07/2014 0:00  3.081667e+05         3       1.75         1510      6360
# 10/07/2014 0:00  2.034000e+05         4       2.00         2090      6630
#
#                  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df1.loc['Seattle'].loc['02/05/2014 0:00']
# Out:
#                      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 02/05/2014 0:00  2384000.0         5       2.50         3650      9050
# 02/05/2014 0:00   490000.0         2       1.00          880      6380
# 02/05/2014 0:00   640000.0         4       2.00         1520      6200
# 02/05/2014 0:00  1400000.0         4       2.50         2920      4000
# 02/05/2014 0:00   365000.0         3       1.00         1090      6435
# 02/05/2014 0:00  1200000.0         5       2.75         2910      9480
# 02/05/2014 0:00   750000.0         3       1.75         2240     10578
# 02/05/2014 0:00   626000.0         3       2.25         1750      1572
# 02/05/2014 0:00   495000.0         4       1.75         1600      6380
# 02/05/2014 0:00   615000.0         3       1.75         2360      7291
# 02/05/2014 0:00   790000.0         3       2.50         2600      4750
# 02/05/2014 0:00   650000.0         4       2.00         1820      5000
# ...
